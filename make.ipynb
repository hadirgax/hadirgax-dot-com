# %% [markdown]
# # Script To Make Site
#
# This script converts all jupyter notebooks into markdown files, then converts all markdown files (jupyter and note) into a website ready to push to github.

# %% [markdown]
# ## Preliminaries

# %%
# Load libraries
import os
import re
import fileinput
import sys
from glob import glob
import shutil


# Create path to content
path = 'content/'

# %% [markdown]
# ## Find All Jupyter Notebooks

# %%
# Find all jupyter notebooks in all content folders
all_ipynb_files = [os.path.join(root, name)
                   for root, dirs, files in os.walk(path)
                       for name in files
                           if name.endswith((".ipynb"))]

print(all_ipynb_files, "\n")

# Remove all notebooks from checkpoint folders
ipynb_files = [ x for x in all_ipynb_files if ".ipynb_checkpoints" not in x ]

print(ipynb_files)
# Out:
# ['content/Git\\gitignore-file.ipynb', 'content/Git\\.ipynb_checkpoints\\gitignore-file-checkpoint.ipynb', 'content/Julia\\read-write-files-in-julia.ipynb', 'content/Julia\\working-with-dates-and-time-functions.ipynb', 'content/Julia\\.ipynb_checkpoints\\read-write files in julia-checkpoint.ipynb', 'content/Julia\\.ipynb_checkpoints\\working with dates and time functions-checkpoint.ipynb', 'content/LaTex\\math-symbols.ipynb', 'content/LaTex\\.ipynb_checkpoints\\Math Symbols-checkpoint.ipynb', 'content/operations-research\\TSP-formulation.ipynb', 'content/operations-research\\TSP-gurobipy.ipynb', 'content/operations-research\\.ipynb_checkpoints\\travel-salesman-problem-checkpoint.ipynb', 'content/operations-research\\.ipynb_checkpoints\\TSP-formulation-checkpoint.ipynb', 'content/operations-research\\.ipynb_checkpoints\\TSP-gurobipy-checkpoint.ipynb', 'content/wordpress\\change-site-URL.ipynb', 'content/wordpress\\Solving-the-ERR_TOO_MANY_REDIRECTS-error.ipynb', 'content/wordpress\\.ipynb_checkpoints\\change site URL-checkpoint.ipynb', 'content/wordpress\\.ipynb_checkpoints\\change-site-URL-checkpoint.ipynb', 'content/wordpress\\.ipynb_checkpoints\\Solving the ERR_TOO_MANY_REDIRECTS error-checkpoint.ipynb', 'content/wordpress\\.ipynb_checkpoints\\Solving-the-ERR_TOO_MANY_REDIRECTS-error-checkpoint.ipynb']
#
# ['content/Git\\gitignore-file.ipynb', 'content/Julia\\read-write-files-in-julia.ipynb', 'content/Julia\\working-with-dates-and-time-functions.ipynb', 'content/LaTex\\math-symbols.ipynb', 'content/operations-research\\TSP-formulation.ipynb', 'content/operations-research\\TSP-gurobipy.ipynb', 'content/wordpress\\change-site-URL.ipynb', 'content/wordpress\\Solving-the-ERR_TOO_MANY_REDIRECTS-error.ipynb']

# %% [markdown]
# ## Convert All Jupyter Notebooks To Markdown

# %%
# For each file
for file in ipynb_files:
    # Convert into markdown
    os.system(f"jupyter nbconvert --to markdown {file}")

# %% [markdown]
# ## Handle The Folders
#
# This really nasty code finds all the folders generated by the Juypter conversion (they end in `_files`) and then tries to rename them to remove the `_files` part (doing so is required by Hugo so the images can be seen). If an existing folder (without the `_files` part) exists, it moves all the files from the newly generated `_files` into the existing folder (so we retain any manual images like flashcard images in that existing folder) and then deletes the `_files` folder.

# %%
# Get all folders in directory
folders = [x[0] for x in os.walk(path)]

# Delete .ipynb checkpoint folders
folders = [ x for x in folders if ".ipynb_checkpoints" not in x ]

# For each folder
for folder_name in folders:
    # if _files in folder name
    if '_files' in folder_name:
        
        # Create a new folder name
        def rchop(thestring, ending):
            if thestring.endswith(ending):
                return thestring[:-len(ending)]
            return thestring

        new_folder_name = rchop(folder_name, '_files')
        
        # try to rename original folder
        try:
            os.rename(folder_name, new_folder_name)
            # if error, 
        except OSError:
            existing_base_folder = os.getcwd()+"/"+new_folder_name
            justcreated_base_folder = os.getcwd()+"/"+folder_name
                 
            # get a list of all files in the folder
            generated_files = os.listdir(justcreated_base_folder)
            
            # copy each file to the existing folder
            for generated_file in generated_files:
                to_copy = justcreated_base_folder+"/"+generated_file
                shutil.copy(to_copy, existing_base_folder)
  
            # delete the newly created _files folder
            shutil.rmtree(justcreated_base_folder)

# %% [markdown]
# ## Search Through Contents Of All Markdown Files (manually generated and generated by a jupyter notebook) And Fix Links So That They Point To Folders Created Above

# %%
def replaceAll(file,searchExp,replaceExp):
    for line in fileinput.input(file, inplace=1):
        if searchExp in line:
            line = line.replace(searchExp,replaceExp)
        sys.stdout.write(line)

# Find all markdown files in all content folders
all_md_files = [os.path.join(root, name)
               for root, dirs, files in os.walk(path)
               for name in files
               if name.endswith((".md"))]

for file in all_md_files:
    with open(file,'r') as f:
        filedata = f.read()
        # Find all markdown link syntaxes
        md_links = re.findall('!\\[[^\\]]+\\]\\([^)]+\\)', filedata)

        # For each markdown link
        for link in md_links:
            # Replace the full file path
            md_image_path = re.search(r'\((.*?)\)', link).group(1)
            md_image_filename = os.path.basename(md_image_path)
            md_image_title = re.search(r'\[(.*?)\]', link).group(1)

            new_link = "!["+md_image_title+"]("+md_image_filename+")"

            replaceAll(file, link, new_link)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-9e6a26fc4f5b> in <module>()
#      13 for file in all_md_files:
#      14     with open(file,'r') as f:
# ---> 15         filedata = f.read()
#      16         # Find all markdown link syntaxes
#      17         md_links = re.findall('!\\[[^\\]]+\\]\\([^)]+\\)', filedata)
#
# c:\python36\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 3045: character maps to <undefined>
